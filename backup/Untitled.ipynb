# %%
import json
data = None
with open("110ORB.json", "r") as fin:
    data = json.load(fin)

# %%
import numpy as np

population = np.asarray([len(i) for i in data["clusters"]])
total = np.sum(population)
total
# Out:
# 1062576

# %%
population/total
# Out:
# array([0.01607791, 0.00342281, 0.00612286, 0.01064677, 0.00520527,
#        0.01625296, 0.01633765, 0.0166501 , 0.00620944, 0.01414111,
#        0.00647013, 0.00736888, 0.00583864, 0.00876455, 0.00540761,
#        0.00624802, 0.01074747, 0.00921911, 0.00376632, 0.00885019,
#        0.00280262, 0.00834858, 0.02205207, 0.00639672, 0.0059751 ,
#        0.00623767, 0.00382749, 0.00508387, 0.01743687, 0.01308518,
#        0.00952873, 0.00797778, 0.00335223, 0.01161517, 0.01465683,
#        0.00817353, 0.00153777, 0.01098839, 0.0075684 , 0.01453449,
#        0.00742065, 0.01515092, 0.00587629, 0.00170341, 0.00543302,
#        0.02386747, 0.00344258, 0.00691715, 0.00394042, 0.01054607,
#        0.00349246, 0.00630261, 0.00050538, 0.00144648, 0.00686445,
#        0.01067406, 0.02247745, 0.01072864, 0.00703573, 0.00933769,
#        0.01372137, 0.01109285, 0.0093518 , 0.00628096, 0.00573982,
#        0.01299954, 0.00300967, 0.01119732, 0.00211561, 0.01913745,
# ...
